# %%
import matplotlib.pyplot as plt
import os 
import sys 
import csv
import numpy as np
import seaborn as sns
import pandas as pd
import scipy
from scipy import stats
from matplotlib.backends.backend_pdf import PdfPages

# %matplotlib inline

# %%
USAGE_STR = """

# Purpose
# Compare the distribution of amino acid sequence conservation for residues
# that are part of the conserved active or inactive state network versus 
# residues that are not. 

"""

# %%
def pos_to_conservation(SEQ_CONSERVE_TABLE):
    """
        For positions that are in TM1 through TM 7. Identify the maximimum frequency in 
        the amino acid distribution
    """
    def skip_position(pos):
        if(pos == "None"): return True
        tm, pos = map(int, pos.split("x"))
        if(tm <1 or tm > 7): return True
        if(pos > 99): return True
        return False
        
    
    with open(SEQ_CONSERVE_TABLE, 'rU') as f: 
        reader = csv.reader(f, delimiter="\t")
        d = list(reader)
    darr = np.array(d)
    column_labels = list(darr[0,:])
    
    pos_to_conserve = {}
    for row in darr[1:]:
        gpcrdb = row[0]
        if(skip_position(gpcrdb) == True): continue
        max_freq = max(map(float, row[1:]))
        pos_to_conserve[gpcrdb] = max_freq
        
    return pos_to_conserve
    
def in_network_residues(l1, l2):
    def get_resi(l):
        f = open(l, 'r')
        network_residues = set()
        for line in f:
            gpcrdb1, gpcrdb2 = line.strip().split("\t")
            network_residues.add(gpcrdb1)
            network_residues.add(gpcrdb2)
        return network_residues
        
    network_residues = get_resi(l1)
    network_residues |= get_resi(l2)
    return network_residues
    
    
# def boxplot(pos_to_conserve, network_residues):
#     in_network_freq = []
#     out_network_freq = []
#     for gpcrdb in pos_to_conserve:
#         freq = pos_to_conserve[gpcrdb]
#         if(gpcrdb in network_residues):
#             print(gpcrdb, freq)
#             in_network_freq.append(freq)
#         else:
#             out_network_freq.append(freq)
    
#     print(len(in_network_freq), len(out_network_freq))
            
#     ### Boxplot
#     plt.figure(figsize = (10,6))
#     labels = ["Conserved Network Residues", "Others"]
#     plt.boxplot([in_network_freq, out_network_freq])
#     plt.xticks(range(1, len(labels) + 1), labels, rotation="horizontal", fontsize=14)
#     plt.title("Distribution of positional residue conservation", fontsize=18)
#     plt.ylabel("Sequence conservation", fontsize=14)

#     return in_network_freq, out_network_freq

def boxplot_seaborne(pos_to_conserve, network_residues):
    position = []
    label = []
    freqs = []
    
    in_network_freq, out_network_freq = [], []
    for gpcrdb in pos_to_conserve:
        freq = pos_to_conserve[gpcrdb]
        position.append(gpcrdb)
        freqs.append(freq)
        if(gpcrdb in network_residues):
            in_network_freq.append(freq)
            label.append("Conserved Network Residues")
        else:
            out_network_freq.append(freq)
            label.append("Others")
    
            
    ### Boxplot
    df = pd.DataFrame({"position": position, "label": label, "freqs": freqs})
    sns.set_style("whitegrid")
    plt.figure(figsize = (9,6))
    ax = sns.boxplot(x="label", y="freqs", data=df, color="White", width=0.3, order = ["Conserved Network Residues", "Others"])
    plt.xticks(rotation=90, fontsize=14)
    plt.title("Distribution of positional residue conservation", fontsize=18)
    plt.ylabel("Sequence conservation", fontsize=14)
    plt.xlabel("")

    return in_network_freq, out_network_freq

def wilcoxan_test(d1, d2):
    s,p = scipy.stats.kruskal(d1,d2)
    print(s,p)

# %%
SEQ_CONSERVE_TABLE="/scratch/PI/rondror/akma327/DynamicNetworks/data/crystal-analysis/simulation-analysis/gpcrdb-freq-config/gpcrdb_residue_conservation.txt"
pos_to_conserve = pos_to_conservation(SEQ_CONSERVE_TABLE)

# %%
ACTIVE_LIST = "/scratch/PI/rondror/akma327/DynamicNetworks/data/crystal-analysis/competing-network-analysis/pymol-visualization/040417/active-heatmap/01-pdb/interaction_list_sim_cutoff60_ALL.txt"
INACTIVE_LIST = "/scratch/PI/rondror/akma327/DynamicNetworks/data/crystal-analysis/competing-network-analysis/pymol-visualization/040417/inactive-heatmap/01-pdb/interaction_list_sim_cutoff60_ALL.txt"
network_residues = in_network_residues(ACTIVE_LIST, INACTIVE_LIST)
in_network_freq, out_network_freq =  boxplot_seaborne(pos_to_conserve, network_residues)
# print("medians", in_network_freq, out_network_freq)
wilcoxan_test(in_network_freq, out_network_freq)
# Out:
# ('medians', [0.77459, 0.9959, 0.96311, 0.69421, 0.38272, 0.73251, 0.77459, 0.33333, 0.45041, 0.90909, 0.77686, 0.22727, 0.97131], [0.22131, 0.2582, 0.18852, 0.27869, 0.2377, 0.37295, 0.22951, 0.18033, 0.23967, 0.39344, 0.7418, 0.1875, 0.1875, 0.29098, 0.24402, 0.11043, 0.26667, 0.34211, 0.12883, 0.13571, 0.12308, 0.2, 0.23077, 0.18182, 0.17647, 0.30769, 0.30328, 0.39754, 0.20082, 0.37295, 0.31557, 0.56967, 0.56967, 0.63934, 0.34016, 0.38115, 0.28689, 0.40984, 0.42213, 0.25, 0.95902, 0.31148, 0.35656, 0.88525, 0.34025, 0.16034, 0.13675, 0.3, 0.57787, 0.92213, 0.7623, 0.32787, 0.4959, 0.38525, 0.35656, 0.13525, 0.2582, 0.19262, 0.2377, 0.2459, 0.58607, 0.68443, 0.34426, 0.19262, 0.29918, 0.25, 0.65164, 0.2623, 0.21721, 0.21721, 0.18443, 0.14754, 0.22131, 0.15164, 0.32569, 0.17857, 0.59244, 0.13636, 0.32877, 0.28689, 0.36885, 0.68443, 0.57377, 0.2418, 0.63115, 0.37705, 0.20082, 0.42623, 0.19262, 0.71193, 0.36214, 0.25926, 0.32922, 0.44033, 0.34979, 0.73251, 0.20988, 0.71311, 0.31557, 0.34836, 0.31148, 0.29918, 0.20082, 0.37295, 0.53689, 0.32377, 0.33197, 0.24242, 0.14286, 0.27907, 0.17949, 1.0, 0.21053, 0.22222, 0.14815, 0.18107, 0.18605, 0.3595, 0.99588, 0.28807, 0.28395, 0.15714, 0.12227, 0.95868, 0.34298, 0.24473, 0.27363, 0.26141, 0.44813, 0.10435, 0.26786, 0.40574, 0.4877, 0.15574, 0.23144, 0.26957, 0.57377, 0.21721, 0.29918, 0.15574, 1.0, 0.25, 0.18182, 0.19048, 0.21359, 0.1157, 0.17742, 0.128, 0.21481, 0.22513, 0.15481, 0.33884, 0.39344, 0.25, 0.33333, 0.25, 0.33333, 0.375, 0.38017, 0.66529, 0.27273, 0.33884, 0.32377, 0.22541, 0.40909, 0.19262, 0.28279, 0.40574, 0.82377, 0.45492, 0.25833, 0.425, 0.27083, 0.4, 0.42739, 0.29464, 0.34025, 0.25833, 0.66116, 0.25103, 0.25, 0.19835, 0.29091, 0.28333, 0.21935, 0.10185, 0.12389, 0.20354, 0.17769, 0.11157, 0.2562, 0.34426, 0.14754, 0.13014, 0.13699, 0.30638, 0.41667, 0.1658, 0.14035, 0.18072, 0.14458, 0.27801, 0.18584, 0.34568, 0.11194, 0.25316, 0.14925, 0.27049, 0.6, 0.6, 0.3444, 0.8, 0.21053, 0.5, 0.25532, 1.0, 0.21721, 0.36066, 0.31967, 0.12295, 0.20902, 0.19262, 0.25, 0.16071, 0.26009, 0.17021, 0.17647, 0.42213, 0.19342, 0.20902, 0.12598, 0.13502, 0.19672, 0.1327, 0.11392, 0.23361, 0.22131, 0.2418, 0.27459, 0.31148, 0.40164, 0.33813, 0.495, 0.26702, 0.41975, 0.48971, 0.66393, 0.20902, 0.25, 0.34016, 0.23361, 0.3087, 0.2521, 0.52521, 0.18033])
# (20.326981423836273, 6.5273609315886009e-06)

# %%
in_network_median = np.median(in_network_freq)
print ("in median", in_network_median)
out_network_median = np.median(out_network_freq)
print ("out median", out_network_median)
# Out:
# ('in median', 0.77459)
# ('out median', 0.26956999999999998)

# %%
def get_interactions(f1):
    f = open(f1, 'r')
    interactions = set()
    for line in f:
        gpcrdb1, gpcrdb2 = line.strip().split("\t")
        interactions.add((gpcrdb1, gpcrdb2))
    return interactions

# %%
ACTIVE_LIST = "/scratch/PI/rondror/akma327/DynamicNetworks/data/crystal-analysis/competing-network-analysis/pymol-visualization/040417/active-heatmap/01-pdb/interaction_list_sim_cutoff60_ALL.txt"
INACTIVE_LIST = "/scratch/PI/rondror/akma327/DynamicNetworks/data/crystal-analysis/competing-network-analysis/pymol-visualization/040417/inactive-heatmap/01-pdb/interaction_list_sim_cutoff60_ALL.txt"
i1 = get_interactions(ACTIVE_LIST)
i2 = get_interactions(INACTIVE_LIST)
all_interaction = i1 | i2
print all_interaction
print(len(all_interaction))
# Out:
# set([('6x40', '7x45'), ('2x50', '7x53'), ('5x58', '7x53'), ('6x40', '7x49'), ('7x45', '7x53'), ('6x47', '7x37'), ('3x50', '7x52'), ('3x43', '7x53'), ('1x50', '2x50'), ('3x43', '5x58'), ('6x40', '7x53'), ('1x50', '7x53'), ('6x47', '6x51'), ('7x49', '7x53'), ('6x51', '7x37'), ('7x45', '7x49')])
# 16

# %%
# print(len(i1))
# ac = set()
# for a, b in i1:
#     ac.add(a)
#     ac.add(b)
# print(ac, len(ac))


print(len(i2))
inac = set()
for a,b in i2:
    inac.add(a)
    inac.add(b)
print(inac, len(inac))
# Out:
# 7
# (set(['6x51', '1x50', '2x50', '7x53', '7x49', '7x45', '6x47', '7x37']), 8)

# %%
# Class A missense mutation box plot

# %%
MISSENSE_FILE="/scratch/PI/rondror/akma327/DynamicNetworks/data/crystal-analysis/simulation-analysis/gpcrdb-freq-config/classA_human_missense_mutations.txt"

def pos_to_snpcount(MISSENSE_FILE):
    """
        Return: {"1x50": 20, "2x50": 23, ...}
        Mapping from position to number of missense mutations 
    """
    f = open(MISSENSE_FILE, 'r')
    pos_to_snpcount_dict = {} # {1x50: number of rows}
    pos_to_weighted_snpcount_dict = # {1x50: sum of allele freqs}
    for line in f:
        linfo = line.strip().split("\t")
        gpcrdb = linfo[2]
        allele_freq = float(linfo[-1])
        

pos_to_snpcount = pos_to_snpcount(MISSENSE_FILE)
# Out:
# 5HT1A_HUMAN	418	None	K/T	deleterious(0.01)	possibly_damaging(0.886)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	413	8x56	K/N	deleterious(0.0)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	410	8x53	A/G	deleterious(0.01)	probably_damaging(0.998)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	397	7x50	P/L	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	390	7x42	Y/H	deleterious(0.0)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	389	7x41	G/D	deleterious(0.03)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	387	7x39	W/R	deleterious(0.0)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	382	7x34	G/S	tolerated(0.48)	possibly_damaging(0.524)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	379	7x31	T/N	tolerated(0.41)	benign(0.004)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	370	None	F/C	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	369	None	P/L	deleterious(0.0)	probably_damaging(0.943)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	367	6x57	V/I	tolerated(0.2)	benign(0.099)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1A_HUMAN	364	6x54	V/M	tolerated(0.24)	probably_damaging(0.984)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	363	6x53	I/L	tolerated(0.08)	possibly_damaging(0.454)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	361	6x51	F/L	deleterious(0.0)	possibly_damaging(0.559)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	356	6x46	L/I	tolerated(0.49)	possibly_damaging(0.645)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	346	6x36	T/M	deleterious(0.0)	probably_damaging(0.996)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# 5HT1A_HUMAN	341	6x31	R/K	tolerated(0.1)	benign(0.12)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	341	6x31	R/M	deleterious(0.0)	probably_damaging(0.981)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	339	6x29	R/P	deleterious(0.0)	probably_damaging(0.997)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000025
#
# 5HT1A_HUMAN	335	6x25	M/I	tolerated(0.59)	benign(0.01)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000058
#
# 5HT1A_HUMAN	334	6x24	K/Q	deleterious(0.02)	probably_damaging(0.955)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000264
#
# 5HT1A_HUMAN	333	None	R/L	deleterious(0.0)	probably_damaging(0.982)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	332	None	K/T	deleterious(0.04)	probably_damaging(0.93)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	331	None	A/G	deleterious(0.03)	benign(0.182)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	330	None	E/D	tolerated(0.21)	benign(0.097)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	325	None	N/T	tolerated(0.26)	possibly_damaging(0.61)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	324	None	K/E	tolerated(0.24)	benign(0.314)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	317	None	A/V	tolerated(0.59)	benign(0.004)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	317	None	A/P	tolerated(0.41)	benign(0.006)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	315	None	P/R	deleterious(0.05)	possibly_damaging(0.723)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	315	None	P/L	deleterious(0.03)	benign(0.305)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1A_HUMAN	314	None	T/N	tolerated(0.54)	benign(0.003)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1A_HUMAN	311	None	A/T	tolerated(0.43)	benign(0.077)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1A_HUMAN	310	None	E/K	tolerated(0.82)	benign(0.052)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1A_HUMAN	309	None	S/R	tolerated(0.54)	benign(0.023)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1A_HUMAN	306	None	P/L	tolerated(0.14)	probably_damaging(0.939)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1A_HUMAN	306	None	P/S	tolerated(0.41)	possibly_damaging(0.483)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	304	None	H/Q	tolerated(0.45)	possibly_damaging(0.906)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	301	None	S/F	deleterious(0.0)	benign(0.25)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000041
#
# 5HT1A_HUMAN	300	None	N/S	tolerated(0.6)	benign(0.002)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000082
#
# 5HT1A_HUMAN	300	None	N/I	deleterious(0.05)	benign(0.005)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	298	None	V/L	tolerated(0.65)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	297	None	R/G	tolerated(0.45)	benign(0.134)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	295	None	V/L	tolerated(0.48)	benign(0.07)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	294	None	E/Q	tolerated(0.13)	probably_damaging(0.99)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1A_HUMAN	285	None	D/E	tolerated(1.0)	benign(0.005)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1A_HUMAN	285	None	D/E	tolerated(1.0)	benign(0.005)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	275	None	L/V	tolerated(0.38)	benign(0.002)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	274	None	A/G	tolerated(0.4)	benign(0.002)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000066
#
# 5HT1A_HUMAN	273	None	G/D	tolerated(0.56)	benign(0.243)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.001557
#
# 5HT1A_HUMAN	273	None	G/V	tolerated(0.3)	benign(0.016)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	273	None	G/S	tolerated(0.84)	benign(0.016)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1A_HUMAN	272	None	G/R	tolerated(0.53)	benign(0.034)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	269	None	S/R	tolerated(0.47)	benign(0.005)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	269	None	S/T	tolerated(0.55)	benign(0.003)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	267	None	V/L	tolerated(0.34)	benign(0.006)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	262	None	N/S	tolerated(1.0)	benign(0.002)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	251	None	K/N	tolerated(0.33)	benign(0.261)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	250	None	P/S	tolerated(0.76)	benign(0.003)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000049
#
# 5HT1A_HUMAN	247	None	A/V	tolerated(0.26)	benign(0.028)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	247	None	A/T	tolerated(0.28)	benign(0.029)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1A_HUMAN	245	None	S/F	tolerated(0.1)	possibly_damaging(0.649)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	244	None	A/T	tolerated(0.68)	benign(0.003)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000033
#
# 5HT1A_HUMAN	243	None	G/A	tolerated(0.72)	benign(0.003)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	242	None	H/Q	tolerated(0.63)	benign(0.011)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	241	None	R/H	tolerated(0.12)	benign(0.003)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1A_HUMAN	241	None	R/G	tolerated(0.38)	benign(0.003)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	240	None	T/P	tolerated(0.11)	benign(0.311)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.012746
#
# 5HT1A_HUMAN	239	None	D/A	tolerated(0.24)	benign(0.239)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	239	None	D/G	tolerated(0.09)	benign(0.004)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1A_HUMAN	237	None	G/R	tolerated(0.48)	benign(0.003)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000066
#
# 5HT1A_HUMAN	236	None	T/I	tolerated(0.14)	benign(0.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	223	5x66	R/H	deleterious(0.03)	probably_damaging(0.998)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	223	5x66	R/C	deleterious(0.0)	probably_damaging(0.998)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	222	5x65	A/V	deleterious(0.0)	probably_damaging(0.997)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	220	5x63	R/L	tolerated(0.15)	possibly_damaging(0.647)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.003599
#
# 5HT1A_HUMAN	219	5x62	F/L	deleterious(0.02)	possibly_damaging(0.593)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	218	5x61	I/K	deleterious(0.0)	probably_damaging(0.993)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	217	5x60	R/L	deleterious(0.0)	probably_damaging(0.932)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	215	5x58	Y/C	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	208	5x51	L/P	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1A_HUMAN	205	5x48	Y/C	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	199	5x43	S/P	deleterious(0.01)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	197	5x41	I/V	tolerated(0.31)	possibly_damaging(0.773)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	193	5x37	H/R	tolerated(0.37)	benign(0.189)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1A_HUMAN	192	None	D/G	deleterious(0.01)	probably_damaging(0.992)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	192	None	D/V	deleterious(0.0)	probably_damaging(0.997)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	188	45x51	T/S	tolerated(0.28)	benign(0.088)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	186	None	A/E	tolerated(0.46)	benign(0.247)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	186	None	A/T	tolerated(0.47)	benign(0.377)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	184	None	P/T	tolerated(0.2)	possibly_damaging(0.895)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	182	None	S/L	tolerated(0.25)	benign(0.008)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000552
#
# 5HT1A_HUMAN	171	4x60	P/L	deleterious(0.0)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	168	4x57	S/F	deleterious(0.0)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1A_HUMAN	167	4x56	I/M	deleterious(0.0)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	167	4x56	I/L	deleterious(0.01)	probably_damaging(0.999)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000041
#
# 5HT1A_HUMAN	167	4x56	I/F	deleterious(0.0)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	155	4x44	A/G	deleterious(0.02)	possibly_damaging(0.678)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000552
#
# 5HT1A_HUMAN	152	4x41	R/L	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	151	4x40	R/W	deleterious(0.0)	probably_damaging(0.995)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	150	4x39	P/R	deleterious(0.01)	probably_damaging(0.995)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	148	34x57	R/S	deleterious(0.02)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	145	34x54	V/M	tolerated(0.27)	benign(0.265)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# 5HT1A_HUMAN	145	34x54	V/L	tolerated(0.1)	benign(0.129)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# 5HT1A_HUMAN	144	34x53	Y/C	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# 5HT1A_HUMAN	142	34x51	I/T	deleterious(0.0)	probably_damaging(0.983)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# 5HT1A_HUMAN	139	3x55	T/M	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000016
#
# 5HT1A_HUMAN	134	3x50	R/S	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# 5HT1A_HUMAN	129	3x45	A/S	deleterious(0.03)	probably_damaging(0.993)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	124	3x40	I/N	deleterious(0.0)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	119	3x35	C/S	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	115	3x31	L/F	tolerated(0.28)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1A_HUMAN	113	3x29	I/T	tolerated(0.57)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	111	3x27	L/V	tolerated(0.1)	benign(0.351)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000033
#
# 5HT1A_HUMAN	99	2x66	L/F	tolerated(0.45)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000132
#
# 5HT1A_HUMAN	94	2x61	A/P	deleterious(0.01)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	69	12x52	N/T	tolerated(0.37)	benign(0.147)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	65	12x48	R/S	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	62	1x58	A/V	tolerated(1.0)	benign(0.012)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	61	1x57	I/M	deleterious(0.0)	probably_damaging(0.997)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	61	1x57	I/V	tolerated(0.13)	possibly_damaging(0.721)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	53	1x49	G/V	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	51	1x47	V/L	deleterious(0.03)	benign(0.004)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	50	1x46	A/G	tolerated(0.09)	benign(0.019)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1A_HUMAN	39	1x35	T/I	deleterious(0.05)	possibly_damaging(0.839)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000049
#
# 5HT1A_HUMAN	33	1x29	V/I	tolerated(0.07)	benign(0.008)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1A_HUMAN	31	None	V/M	deleterious(0.02)	benign(0.022)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	30	None	D/E	tolerated(1.0)	benign(0.004)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	30	None	D/E	tolerated(1.0)	benign(0.004)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	28	None	I/V	tolerated(0.66)	benign(0.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.008838
#
# 5HT1A_HUMAN	25	None	T/A	tolerated(0.96)	benign(0.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	23	None	G/D	tolerated_low_confidence(0.3)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	22	None	G/S	tolerated(0.4)	benign(0.002)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000190
#
# 5HT1A_HUMAN	18	None	P/L	tolerated_low_confidence(0.34)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	18	None	P/S	tolerated_low_confidence(0.7)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000017
#
# 5HT1A_HUMAN	17	None	A/S	tolerated_low_confidence(0.76)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	16	None	P/L	tolerated_low_confidence(0.31)	benign(0.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.001626
#
# 5HT1A_HUMAN	12	None	T/S	tolerated_low_confidence(0.21)	possibly_damaging(0.556)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000017
#
# 5HT1A_HUMAN	11	None	N/S	tolerated_low_confidence(0.29)	benign(0.043)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1A_HUMAN	11	None	N/T	tolerated_low_confidence(0.09)	benign(0.342)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000041
#
# 5HT1A_HUMAN	9	None	G/S	tolerated_low_confidence(0.47)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000041
#
# 5HT1A_HUMAN	3	None	V/M	tolerated_low_confidence(0.27)	benign(0.007)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000728
#
# 5HT1A_HUMAN	2	None	D/G	deleterious_low_confidence(0.01)	benign(0.282)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	389	None	T/A	tolerated_low_confidence(0.56)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	385	None	R/P	tolerated(0.07)	benign(0.01)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	385	None	R/C	deleterious(0.03)	benign(0.028)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	384	8x58	I/M	tolerated(0.14)	benign(0.011)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	368	7x52	I/T	deleterious(0.0)	probably_damaging(0.994)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	367	7x51	I/V	tolerated(0.54)	benign(0.014)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1B_HUMAN	366	7x50	P/R	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	362	7x46	S/C	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	362	7x46	S/F	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	359	7x42	Y/C	deleterious(0.0)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	350	7x33	I/V	tolerated(0.25)	benign(0.006)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1B_HUMAN	346	None	F/L	tolerated(0.43)	benign(0.01)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000115
#
# 5HT1B_HUMAN	345	None	W/L	tolerated(0.63)	possibly_damaging(0.484)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	339	None	I/S	deleterious(0.03)	possibly_damaging(0.544)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	337	6x58	M/L	tolerated(0.58)	benign(0.001)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1B_HUMAN	328	6x49	L/P	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	325	6x46	V/M	deleterious(0.03)	benign(0.314)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	322	6x43	A/D	deleterious(0.0)	possibly_damaging(0.903)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	318	6x39	I/V	tolerated(0.11)	benign(0.074)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	317	6x38	G/R	deleterious(0.0)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	310	6x31	R/L	deleterious(0.0)	probably_damaging(0.99)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	310	6x31	R/P	deleterious(0.0)	probably_damaging(0.995)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	307	6x28	A/S	tolerated(0.34)	probably_damaging(0.985)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	307	6x28	A/T	tolerated(0.28)	possibly_damaging(0.85)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	305	6x26	M/T	tolerated(0.25)	benign(0.004)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	294	None	V/I	tolerated(0.2)	benign(0.005)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	292	None	V/M	tolerated(0.06)	possibly_damaging(0.542)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	286	None	Y/F	tolerated(0.73)	benign(0.01)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	286	None	Y/S	tolerated(0.46)	benign(0.03)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	279	None	S/R	deleterious(0.04)	benign(0.244)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	270	None	I/M	tolerated(0.24)	benign(0.016)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	270	None	I/V	tolerated(0.59)	benign(0.003)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	267	None	V/I	tolerated(0.45)	benign(0.014)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	262	None	G/R	tolerated(0.17)	possibly_damaging(0.615)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000074
#
# 5HT1B_HUMAN	260	None	S/Y	deleterious(0.01)	probably_damaging(0.992)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	259	None	D/N	tolerated(0.53)	benign(0.006)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	259	None	D/Y	deleterious(0.02)	possibly_damaging(0.679)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	253	None	R/Q	tolerated(0.58)	benign(0.108)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	246	5x76	R/G	tolerated(0.14)	benign(0.063)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	244	5x74	P/R	deleterious(0.03)	benign(0.179)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# 5HT1B_HUMAN	244	5x74	P/L	deleterious(0.01)	benign(0.3)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# 5HT1B_HUMAN	244	5x74	P/A	tolerated(0.31)	possibly_damaging(0.542)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# 5HT1B_HUMAN	233	5x63	V/L	tolerated(0.78)	benign(0.015)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000058
#
# 5HT1B_HUMAN	233	5x63	V/L	tolerated(0.78)	benign(0.015)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	233	5x63	V/I	tolerated(0.45)	benign(0.025)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	230	5x60	R/H	deleterious(0.0)	possibly_damaging(0.818)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000181
#
# 5HT1B_HUMAN	230	5x60	R/S	deleterious(0.0)	probably_damaging(0.983)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	225	5x55	I/T	deleterious(0.0)	possibly_damaging(0.643)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000247
#
# 5HT1B_HUMAN	225	5x55	I/V	tolerated(0.23)	benign(0.123)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	221	5x51	T/N	tolerated(0.06)	possibly_damaging(0.493)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	220	5x50	P/S	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	219	5x49	F/L	tolerated(0.1)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	219	5x49	F/L	tolerated(0.1)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	210	5x41	V/F	deleterious(0.0)	possibly_damaging(0.457)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000058
#
# 5HT1B_HUMAN	206	5x37	I/V	tolerated(0.4)	benign(0.015)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	200	None	V/M	tolerated(0.22)	benign(0.01)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	193	None	E/Q	tolerated(0.56)	benign(0.016)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	193	None	E/K	tolerated(0.71)	benign(0.108)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	186	None	F/L	tolerated(0.16)	possibly_damaging(0.614)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	174	4x50	W/C	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	173	4x49	V/A	tolerated(0.2)	possibly_damaging(0.498)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	167	4x43	A/V	deleterious(0.02)	benign(0.126)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	166	4x42	A/T	deleterious(0.0)	probably_damaging(0.912)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	163	4x39	P/T	tolerated(0.18)	benign(0.159)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	161	34x57	R/S	deleterious(0.0)	probably_damaging(0.934)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	160	34x56	K/T	deleterious(0.0)	benign(0.145)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	156	34x52	E/D	deleterious(0.01)	benign(0.018)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1B_HUMAN	155	34x51	V/A	deleterious(0.04)	possibly_damaging(0.696)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# 5HT1B_HUMAN	155	34x51	V/L	tolerated(0.5)	benign(0.042)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# 5HT1B_HUMAN	151	3x54	I/F	deleterious(0.0)	probably_damaging(0.996)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# 5HT1B_HUMAN	150	3x53	A/S	deleterious(0.0)	probably_damaging(0.953)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000033
#
# 5HT1B_HUMAN	142	3x45	V/A	tolerated(0.47)	benign(0.105)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	141	3x44	C/S	tolerated(0.13)	probably_damaging(0.993)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	127	3x30	S/L	tolerated(0.05)	possibly_damaging(0.597)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000041
#
# 5HT1B_HUMAN	124	3x27	F/C	deleterious(0.0)	possibly_damaging(0.586)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.009249
#
# 5HT1B_HUMAN	112	2x66	T/N	tolerated(0.13)	benign(0.091)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000049
#
# 5HT1B_HUMAN	112	2x66	T/S	tolerated(0.67)	benign(0.021)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000058
#
# 5HT1B_HUMAN	110	2x64	T/S	deleterious(0.02)	possibly_damaging(0.855)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	106	2x60	S/G	deleterious(0.01)	benign(0.05)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	93	2x48	V/F	tolerated(0.07)	benign(0.072)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	92	2x47	A/V	deleterious(0.0)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	92	2x47	A/T	deleterious(0.0)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	76	1x59	R/W	tolerated(0.07)	possibly_damaging(0.901)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	73	1x56	T/I	deleterious(0.02)	probably_damaging(0.978)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	71	1x54	I/T	deleterious(0.0)	benign(0.349)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	68	1x51	A/T	tolerated(0.13)	benign(0.05)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	67	1x50	N/S	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	66	1x49	S/F	tolerated(0.2)	benign(0.179)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	60	1x43	T/I	deleterious(0.0)	probably_damaging(0.991)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	58	1x41	L/V	tolerated(1.0)	benign(0.021)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	51	1x34	L/P	tolerated(0.14)	benign(0.424)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	50	1x33	V/I	tolerated(1.0)	benign(0.007)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	49	1x32	K/T	deleterious(0.01)	possibly_damaging(0.703)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	47	1x30	P/T	tolerated(0.29)	benign(0.039)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	47	1x30	P/S	tolerated(0.52)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	45	None	S/P	tolerated(0.3)	benign(0.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	39	None	I/V	tolerated(0.84)	benign(0.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1B_HUMAN	35	None	A/V	tolerated(0.18)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	35	None	A/T	tolerated(0.43)	benign(0.017)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	30	None	S/C	deleterious(0.01)	benign(0.315)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	29	None	P/S	tolerated(0.68)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	28	None	A/T	tolerated(0.65)	benign(0.002)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	27	None	S/F	tolerated(0.23)	benign(0.085)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000124
#
# 5HT1B_HUMAN	22	None	Q/P	tolerated_low_confidence(0.25)	benign(0.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1B_HUMAN	21	None	P/S	tolerated_low_confidence(0.81)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	19	None	W/C	tolerated_low_confidence(0.19)	benign(0.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	16	None	S/F	tolerated_low_confidence(0.28)	benign(0.07)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	13	None	P/L	tolerated_low_confidence(0.17)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000132
#
# 5HT1B_HUMAN	13	None	P/S	tolerated_low_confidence(0.6)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	12	None	P/S	tolerated_low_confidence(0.75)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	9	None	A/V	tolerated_low_confidence(0.3)	possibly_damaging(0.739)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	5	None	G/D	tolerated_low_confidence(0.14)	benign(0.013)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	5	None	G/S	tolerated_low_confidence(0.57)	benign(0.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1B_HUMAN	3	None	E/Q	tolerated_low_confidence(0.29)	benign(0.008)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	376	None	A/V	tolerated_low_confidence(0.49)	benign(0.017)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1D_HUMAN	376	None	A/T	tolerated_low_confidence(0.46)	benign(0.002)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	376	None	A/S	tolerated_low_confidence(0.42)	benign(0.008)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	374	None	R/Q	deleterious(0.02)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000033
#
# 5HT1D_HUMAN	374	None	R/W	deleterious(0.0)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.001334
#
# 5HT1D_HUMAN	372	None	P/T	tolerated(0.06)	benign(0.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	367	8x54	F/S	deleterious(0.0)	probably_damaging(0.997)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	366	8x53	A/V	deleterious(0.0)	probably_damaging(0.997)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000156
#
# 5HT1D_HUMAN	366	8x53	A/G	deleterious(0.0)	probably_damaging(0.996)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000140
#
# 5HT1D_HUMAN	366	8x53	A/D	deleterious(0.0)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1D_HUMAN	365	8x52	Q/R	tolerated(0.41)	benign(0.146)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000074
#
# 5HT1D_HUMAN	364	8x51	R/Q	tolerated(0.13)	benign(0.004)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1D_HUMAN	364	8x51	R/W	deleterious(0.0)	possibly_damaging(0.614)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1D_HUMAN	363	8x50	F/C	deleterious(0.0)	probably_damaging(0.998)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	359	7x56	F/S	tolerated(0.28)	probably_damaging(0.997)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	358	7x55	V/M	tolerated(0.71)	benign(0.019)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# 5HT1D_HUMAN	353	7x50	P/L	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000033
#
# 5HT1D_HUMAN	346	7x42	Y/C	deleterious(0.0)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	345	7x41	G/V	deleterious(0.0)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	342	7x38	T/S	deleterious(0.01)	probably_damaging(0.998)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	335	7x31	P/L	tolerated(0.18)	possibly_damaging(0.65)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	335	7x31	P/S	tolerated(0.36)	possibly_damaging(0.513)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1D_HUMAN	331	None	C/R	deleterious(0.02)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	328	None	R/Q	tolerated(0.6)	benign(0.017)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000033
#
# 5HT1D_HUMAN	328	None	R/W	deleterious(0.0)	possibly_damaging(0.863)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1D_HUMAN	324	6x58	L/F	deleterious(0.04)	possibly_damaging(0.791)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	323	6x57	V/I	tolerated(0.42)	benign(0.094)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1D_HUMAN	319	6x53	V/M	deleterious(0.0)	probably_damaging(0.924)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000041
#
# 5HT1D_HUMAN	319	6x53	V/L	tolerated(0.2)	possibly_damaging(0.478)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1D_HUMAN	319	6x53	V/L	tolerated(0.2)	possibly_damaging(0.478)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	318	6x52	F/V	deleterious(0.0)	probably_damaging(0.999)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1D_HUMAN	318	6x52	F/L	deleterious(0.0)	probably_damaging(0.996)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	309	6x43	A/T	tolerated(0.11)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	307	6x41	L/P	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	297	6x31	R/S	deleterious(0.0)	possibly_damaging(0.742)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	297	6x31	R/G	deleterious(0.01)	possibly_damaging(0.848)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	296	6x30	E/A	deleterious(0.0)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	295	6x29	R/Q	deleterious(0.0)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# 5HT1D_HUMAN	294	6x28	A/V	deleterious(0.05)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1D_HUMAN	293	6x27	A/V	deleterious(0.02)	possibly_damaging(0.549)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000107
#
# 5HT1D_HUMAN	289	None	K/N	tolerated(0.1)	possibly_damaging(0.825)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000049
#
# 5HT1D_HUMAN	289	None	K/N	tolerated(0.1)	possibly_damaging(0.825)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	288	None	R/H	deleterious(0.01)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000033
#
# 5HT1D_HUMAN	288	None	R/C	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000231
#
# 5HT1D_HUMAN	285	None	A/T	tolerated(0.58)	benign(0.077)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	268	None	A/S	tolerated(0.85)	benign(0.01)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	267	None	S/L	tolerated(0.28)	benign(0.006)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000066
#
# 5HT1D_HUMAN	267	None	S/P	tolerated(0.18)	benign(0.006)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1D_HUMAN	266	None	H/L	tolerated(0.74)	benign(0.309)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1D_HUMAN	266	None	H/R	tolerated(0.6)	benign(0.309)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	266	None	H/Y	tolerated(1.0)	possibly_damaging(0.664)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	265	None	S/L	tolerated(0.51)	benign(0.002)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.002570
#
# 5HT1D_HUMAN	261	None	H/Q	tolerated(0.57)	benign(0.016)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000049
#
# 5HT1D_HUMAN	261	None	H/R	tolerated(0.57)	benign(0.243)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	257	None	N/H	tolerated(0.07)	benign(0.035)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1D_HUMAN	255	None	S/W	deleterious(0.01)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1D_HUMAN	255	None	S/L	tolerated(0.1)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000033
#
# 5HT1D_HUMAN	253	None	L/F	tolerated(0.36)	benign(0.186)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	252	None	S/L	deleterious(0.02)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1D_HUMAN	250	None	G/V	deleterious(0.01)	possibly_damaging(0.788)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# 5HT1D_HUMAN	250	None	G/R	deleterious(0.04)	benign(0.089)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000033
#
# 5HT1D_HUMAN	246	None	T/I	tolerated(0.06)	benign(0.112)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	246	None	T/P	tolerated(0.3)	benign(0.004)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	243	None	H/N	tolerated(0.07)	benign(0.111)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	242	None	A/S	tolerated(0.16)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	241	None	T/M	deleterious(0.03)	probably_damaging(0.99)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000321
#
# 5HT1D_HUMAN	238	None	R/H	deleterious(0.01)	benign(0.141)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000049
#
# 5HT1D_HUMAN	238	None	R/C	deleterious(0.0)	probably_damaging(0.976)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	235	5x76	Y/C	tolerated(0.15)	benign(0.006)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# 5HT1D_HUMAN	234	5x75	L/R	tolerated(0.66)	possibly_damaging(0.588)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# 5HT1D_HUMAN	227	5x68	R/H	deleterious(0.03)	benign(0.056)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.001277
#
# ...
#
# FSHR_HUMAN	618	7x45	S/R	tolerated(0.68)	benign(0.002)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	617	7x43	T/I	deleterious(0.04)	benign(0.008)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	616	7x42	V/D	tolerated(0.51)	benign(0.139)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	615	7x41	R/T	tolerated(0.05)	benign(0.062)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	615	7x41	R/K	tolerated(1.0)	benign(0.003)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	614	7x40	P/S	tolerated(0.32)	benign(0.005)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	613	7x39	A/G	tolerated(0.43)	benign(0.011)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	609	7x35	H/Q	tolerated(0.27)	benign(0.098)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	609	7x35	H/Y	tolerated(0.68)	possibly_damaging(0.761)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	605	7x31	P/A	tolerated(0.53)	benign(0.001)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	601	None	H/Q	deleterious(0.04)	probably_damaging(0.968)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000058
#
# FSHR_HUMAN	596	6x59	T/I	tolerated(0.1)	benign(0.029)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	595	6x58	E/D	tolerated(0.07)	benign(0.106)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	593	6x56	R/T	deleterious(0.0)	possibly_damaging(0.739)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	591	6x54	I/S	tolerated(0.06)	benign(0.037)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	587	6x50	M/I	tolerated(0.32)	benign(0.003)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	583	6x46	G/C	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	580	6x43	S/T	deleterious(0.0)	possibly_damaging(0.678)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	574	6x37	D/A	deleterious(0.0)	probably_damaging(0.998)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	572	6x35	R/H	deleterious(0.0)	possibly_damaging(0.881)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000041
#
# FSHR_HUMAN	572	6x35	R/C	deleterious(0.0)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# FSHR_HUMAN	568	6x31	T/A	deleterious(0.0)	probably_damaging(0.996)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	567	None	F/I	deleterious(0.0)	probably_damaging(0.939)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000074
#
# FSHR_HUMAN	628	7x55	I/T	deleterious(0.0)	possibly_damaging(0.847)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# FSHR_HUMAN	564	None	Y/C	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	563	None	L/F	deleterious(0.0)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	562	5x71	F/L	deleterious(0.0)	probably_damaging(0.973)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000016
#
# FSHR_HUMAN	549	5x58	L/P	deleterious(0.0)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	542	5x51	V/M	deleterious(0.0)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	538	5x47	P/S	deleterious(0.0)	possibly_damaging(0.863)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	537	5x46	V/L	tolerated(0.34)	benign(0.005)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	536	5x45	K/E	deleterious(0.0)	possibly_damaging(0.747)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	534	5x43	S/T	deleterious(0.04)	benign(0.044)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# FSHR_HUMAN	531	5x401	I/V	deleterious(0.0)	possibly_damaging(0.45)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# FSHR_HUMAN	529	5x39	F/L	deleterious(0.0)	probably_damaging(0.994)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	528	5x38	F/S	deleterious(0.0)	probably_damaging(0.935)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	521	None	L/F	deleterious(0.01)	benign(0.388)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	519	45x52	D/E	deleterious(0.0)	probably_damaging(0.987)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	516	None	I/S	deleterious(0.0)	probably_damaging(0.998)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	514	None	M/I	tolerated(0.41)	benign(0.001)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	511	None	R/H	deleterious(0.0)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	511	None	R/C	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# FSHR_HUMAN	509	None	A/T	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# FSHR_HUMAN	507	None	R/T	deleterious(0.01)	benign(0.03)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	501	4x57	S/F	deleterious(0.0)	probably_damaging(0.984)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	500	4x56	V/M	tolerated(0.36)	benign(0.033)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000148
#
# FSHR_HUMAN	498	4x54	N/I	deleterious(0.02)	possibly_damaging(0.642)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	496	4x52	N/H	deleterious(0.03)	probably_damaging(0.967)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	495	4x51	R/Q	tolerated(0.3)	probably_damaging(0.985)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000082
#
# FSHR_HUMAN	495	4x51	R/W	deleterious(0.0)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000082
#
# FSHR_HUMAN	493	4x49	T/I	deleterious(0.01)	probably_damaging(0.977)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	491	4x47	Y/S	deleterious(0.0)	probably_damaging(0.999)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# FSHR_HUMAN	486	4x42	C/Y	deleterious(0.0)	probably_damaging(0.996)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	485	4x41	G/S	tolerated(0.19)	benign(0.014)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	483	4x39	I/T	deleterious(0.0)	probably_damaging(0.997)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	474	34x50	V/L	tolerated(0.7)	benign(0.018)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# FSHR_HUMAN	473	3x56	L/H	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	470	3x53	M/I	tolerated(1.0)	benign(0.003)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000049
#
# FSHR_HUMAN	467	3x50	L/P	deleterious(0.01)	possibly_damaging(0.713)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	g_prot	0.000008
#
# FSHR_HUMAN	466	3x49	Q/R	deleterious(0.02)	probably_damaging(0.952)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	466	3x49	Q/K	deleterious(0.03)	possibly_damaging(0.542)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	462	3x45	S/R	deleterious(0.01)	possibly_damaging(0.481)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000346
#
# FSHR_HUMAN	462	3x45	S/R	deleterious(0.01)	possibly_damaging(0.481)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# FSHR_HUMAN	461	3x44	D/V	deleterious(0.0)	possibly_damaging(0.466)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000049
#
# FSHR_HUMAN	460	3x43	I/T	tolerated(0.53)	benign(0.255)	not_binding_pocket_res	not_sodium_pocket_res	activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	458	3x41	M/I	deleterious(0.0)	benign(0.369)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	453	3x36	S/N	deleterious(0.0)	probably_damaging(0.944)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	449	3x32	Y/C	deleterious(0.0)	probably_damaging(1.0)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	446	3x29	I/M	deleterious(0.0)	possibly_damaging(0.89)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	443	3x26	I/M	deleterious(0.05)	benign(0.167)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	443	3x26	I/T	deleterious(0.02)	possibly_damaging(0.628)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	440	3x23	L/V	tolerated(0.12)	possibly_damaging(0.492)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	433	None	I/S	deleterious(0.0)	benign(0.159)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	433	None	I/L	tolerated(1.0)	benign(0.006)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	431	None	G/D	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000025
#
# FSHR_HUMAN	430	None	M/T	tolerated(0.15)	benign(0.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	427	None	V/A	deleterious(0.03)	benign(0.024)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	425	None	A/T	tolerated(0.35)	benign(0.008)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	423	2x65	H/R	deleterious(0.01)	possibly_damaging(0.706)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	422	2x64	R/H	tolerated(0.11)	benign(0.266)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000041
#
# FSHR_HUMAN	422	2x64	R/C	deleterious(0.01)	benign(0.336)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	420	2x62	Q/H	tolerated(0.08)	benign(0.006)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	419	2x61	V/M	deleterious(0.03)	benign(0.298)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	415	2x57	L/R	deleterious(0.02)	possibly_damaging(0.828)	binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	410	2x52	T/M	deleterious(0.0)	probably_damaging(0.995)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	410	2x52	T/K	deleterious(0.0)	probably_damaging(0.917)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	406	2x48	W/L	deleterious(0.0)	probably_damaging(0.961)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	405	2x47	R/K	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	399	2x41	T/I	deleterious(0.01)	benign(0.262)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	399	2x41	T/K	deleterious(0.0)	possibly_damaging(0.87)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	387	1x57	T/N	deleterious(0.0)	probably_damaging(0.981)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	386	1x56	F/L	tolerated(0.26)	benign(0.015)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	384	1x54	G/S	deleterious(0.0)	probably_damaging(0.995)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	382	1x52	A/T	tolerated(0.5)	benign(0.044)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000239
#
# FSHR_HUMAN	381	1x51	D/Y	deleterious(0.01)	benign(0.315)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
#
# FSHR_HUMAN	378	1x48	A/T	deleterious(0.04)	benign(0.253)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	376	1x46	T/I	deleterious(0.0)	probably_damaging(0.95)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	375	1x45	Q/K	deleterious(0.03)	probably_damaging(0.971)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	372	1x42	I/V	deleterious(0.0)	probably_damaging(0.953)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	371	1x41	A/D	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	366	1x36	Q/K	deleterious(0.05)	benign(0.192)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	365	1x35	S/N	tolerated(0.08)	benign(0.162)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	359	1x29	V/A	deleterious(0.0)	possibly_damaging(0.827)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	359	1x29	V/L	deleterious(0.0)	probably_damaging(0.953)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	357	None	A/T	deleterious(0.0)	probably_damaging(0.996)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	350	None	G/E	deleterious(0.0)	probably_damaging(1.0)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	349	None	I/T	tolerated(0.06)	benign(0.053)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	348	None	C/F	deleterious(0.0)	probably_damaging(0.929)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	339	None	M/I	deleterious(0.0)	probably_damaging(0.932)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000008
#
# FSHR_HUMAN	338	None	L/F	deleterious(0.01)	probably_damaging(0.986)	not_binding_pocket_res	not_sodium_pocket_res	not_activation_res	not_g_prot	0.000016
